# %% [markdown]
# <a href="https://colab.research.google.com/github/safimoh1993-star/MNIST-Classification-using-Keras/blob/main/MNIST_Classification_using_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.datasets import mnist

# %%
(x_train,y_train),(x_test,y_test)=mnist.load_data()
x_train=x_train / 255.0
x_test=x_test / 255.0

# %%
model= Sequential([
    Flatten(input_shape=(28,28)),
    Dense(128,activation='relu'),
    Dense(10,activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x_train,y_train,epochs=1,batch_size=64)
# Out:
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8644 - loss: 0.4931

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print("دقة النموذج على بيانات الاختبار:", test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9468 - loss: 0.1834
# دقة النموذج على بيانات الاختبار: 0.9531999826431274

# %%
predictions = model.predict(x_test[:5])
for i, pred in enumerate(predictions):
    print(f"الصورة {i} , النموذج توقع: {pred.argmax()}, القيمة الحقيقية: {y_test[i]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# الصورة 0 , النموذج توقع: 7, القيمة الحقيقية: 7
# الصورة 1 , النموذج توقع: 2, القيمة الحقيقية: 2
# الصورة 2 , النموذج توقع: 1, القيمة الحقيقية: 1
# الصورة 3 , النموذج توقع: 0, القيمة الحقيقية: 0
# الصورة 4 , النموذج توقع: 4, القيمة الحقيقية: 4
